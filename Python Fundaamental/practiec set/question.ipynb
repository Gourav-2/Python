# %% [markdown]
# Q1

# %%
print("Hello, World! Welcome to Python.")
# Out:
# Hello, World! Welcome to Python.

# %% [markdown]
# Q2  Write a program that prints the following poem using a single
# Twinkle, twinkle, little star,
# How I wonder what you are!
# print() statement

# %%
print("Twinkle, twinkle, little star,\nHow I wonder what you are!")
# Out:
# Twinkle, twinkle, little star,
# How I wonder what you are!

# %% [markdown]
# Q3: Variables & Data Types
# Create variables to store: - Your name (string)- Your age (integer)- Your height in meters (float)- A boolean value representing whether you are a student
# Print all of them in one line

# %%
name="Gourav chouhan"
age=19
height=5.5
print(f"my name is {name} and my age is {age} years and i am {height} feet long")
# Out:
# my name is Gourav chouhan and my age is 19and i am 5.5 feet long

# %% [markdown]
# Q4: Typecasting Practice
# You are given a string:
# num = "45"
# Convert it into an integer and add
# 10 to it. Print the result

# %%
num="45"
print(int(num)+10)
# Out:
# 55

# %% [markdown]
# Q5: Taking User Input
# Write a program that:
# 1.
# 2.
# Asks the user for their favorite food.
# Prints:
# Wow! I also like <food>

# %%
food=input("what is your favorite food ")
print("Wow! I also like",food)
# Out:
# Wow! I also like a

# %% [markdown]
# Q6: Simple Calculator
# Write a program that:
# 1. Takes two numbers as input from the user.
# 2. Prints their sum, difference, product, and quotient

# %%
num1=int(input("enter 1st num:"))
num2=int(input("enter 2nd num:"))
print("sum:", num1+num2)
print("difference", num1-num2)
print("product", num1*num2)
print("quotient", num1/num2)
# Out:
# sum: 30
# difference -10
# product 200
# quotient 0.5

# %% [markdown]
# Q7: Escape Sequences
# Print the following output using escape sequences:
# Harry said, "Python is awesome!"
# This is on a new line.
# This is a tab ->    <- here

# %%
print("Harry said, \"Python is awesome!\" \nthis is new line. \nthis is tab ->    <-here")
# Out:
# Harry said, "Python is awesome!"
# this is new line.
# this is tab ->    <-here

# %% [markdown]
# Q8: Operator Challenge
# Write a program that:
# 1.
#
# Takes an integer as input from the user.
# 2.
# Prints the square and cube of that number

# %%
num1=int(input("enter  num:"))

print("Square  :", num1**2)
print("cube  :", num1**3)
# Out:
# Square  : 4
# cube  : 8
